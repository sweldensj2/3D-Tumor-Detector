# %% [markdown]
# # Load Packages and State Paths

# %%
import os
import json
import numpy as np
import cv2
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from torchvision import transforms
import nibabel as nib

final_project_path = '/home/jws2215/e6691-2024spring-project-jwss-jws2215' # vm
data_folder_path = os.path.join(final_project_path, 'BraTS2020')
train_folder_path = os.path.join(data_folder_path, 'train')
valid_folder_path = os.path.join(data_folder_path, 'valid')


if torch.cuda.is_available():
    device = torch.device('cuda')
    print("GPU name: ", torch.cuda.get_device_name(0))
    allocated_memory = torch.cuda.memory_allocated() / (1024 ** 3)  # Convert bytes to gigabytes
    cached_memory = torch.cuda.memory_reserved() / (1024 ** 3)  # Convert bytes to gigabytes
    print(f"Allocated Memory: {allocated_memory:.2f} GB")
    print(f"Cached Memory: {cached_memory:.2f} GB")
    total_memory = torch.cuda.get_device_properties(device).total_memory / (1024 ** 3)  # Convert bytes to gigabytes
    print(f"Total GPU Memory: {total_memory:.2f} GB")
else:
    print("CUDA is not available. Cannot print memory usage.")
    device = torch.device('cpu')
# Out:
# GPU name:  Tesla T4
# Allocated Memory: 0.00 GB
# Cached Memory: 0.00 GB
# Total GPU Memory: 14.58 GB

# %% [markdown]
# # Create the Dataset

# %%
def create_data_dictionary(folder_path):
    data_dict = {}
    subfolders = [f for f in os.listdir(folder_path) if os.path.isdir(os.path.join(folder_path, f))]
    
    for idx, subfolder in enumerate(subfolders):
        abs_path = os.path.join(folder_path, subfolder)
        data_dict[idx] = {'absolute_path': abs_path, 'folder_name': subfolder}
    
    return data_dict

data_path_dictionary_train = create_data_dictionary(train_folder_path)
data_path_dictionary_valid = create_data_dictionary(valid_folder_path)

print("Train Data Dictionary:")
for idx, data in data_path_dictionary_train.items():
    print(f"Index: {idx}, Absolute Path: {data['absolute_path']}, Folder Name: {data['folder_name']}")

print("\nValid Data Dictionary:")
for idx, data in data_path_dictionary_valid.items():
    print(f"Index: {idx}, Absolute Path: {data['absolute_path']}, Folder Name: {data['folder_name']}")
# Out:
# Train Data Dictionary:
# Index: 0, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_099, Folder Name: BraTS20_Training_099
# Index: 1, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_036, Folder Name: BraTS20_Training_036
# Index: 2, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_004, Folder Name: BraTS20_Training_004
# Index: 3, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_029, Folder Name: BraTS20_Training_029
# Index: 4, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_021, Folder Name: BraTS20_Training_021
# Index: 5, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_058, Folder Name: BraTS20_Training_058
# Index: 6, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_072, Folder Name: BraTS20_Training_072
# Index: 7, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_018, Folder Name: BraTS20_Training_018
# Index: 8, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_042, Folder Name: BraTS20_Training_042
# Index: 9, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_050, Folder Name: BraTS20_Training_050
# Index: 10, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_094, Folder Name: BraTS20_Training_094
# Index: 11, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_074, Folder Name: BraTS20_Training_074
# Index: 12, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_012, Folder Name: BraTS20_Training_012
# Index: 13, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_026, Folder Name: BraTS20_Training_026
# Index: 14, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_035, Folder Name: BraTS20_Training_035
# Index: 15, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_041, Folder Name: BraTS20_Training_041
# Index: 16, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_096, Folder Name: BraTS20_Training_096
# Index: 17, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_037, Folder Name: BraTS20_Training_037
# Index: 18, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_071, Folder Name: BraTS20_Training_071
# Index: 19, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_092, Folder Name: BraTS20_Training_092
# Index: 20, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_009, Folder Name: BraTS20_Training_009
# Index: 21, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_073, Folder Name: BraTS20_Training_073
# Index: 22, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_039, Folder Name: BraTS20_Training_039
# Index: 23, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_069, Folder Name: BraTS20_Training_069
# Index: 24, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_043, Folder Name: BraTS20_Training_043
# Index: 25, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_033, Folder Name: BraTS20_Training_033
# Index: 26, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_079, Folder Name: BraTS20_Training_079
# Index: 27, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_068, Folder Name: BraTS20_Training_068
# Index: 28, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_003, Folder Name: BraTS20_Training_003
# Index: 29, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_076, Folder Name: BraTS20_Training_076
# Index: 30, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_065, Folder Name: BraTS20_Training_065
# Index: 31, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_017, Folder Name: BraTS20_Training_017
# Index: 32, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_091, Folder Name: BraTS20_Training_091
# Index: 33, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_034, Folder Name: BraTS20_Training_034
# Index: 34, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_060, Folder Name: BraTS20_Training_060
# Index: 35, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_098, Folder Name: BraTS20_Training_098
# Index: 36, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_027, Folder Name: BraTS20_Training_027
# Index: 37, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_053, Folder Name: BraTS20_Training_053
# Index: 38, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_028, Folder Name: BraTS20_Training_028
# Index: 39, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_054, Folder Name: BraTS20_Training_054
# Index: 40, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_067, Folder Name: BraTS20_Training_067
# Index: 41, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_062, Folder Name: BraTS20_Training_062
# Index: 42, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_064, Folder Name: BraTS20_Training_064
# Index: 43, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_046, Folder Name: BraTS20_Training_046
# Index: 44, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_044, Folder Name: BraTS20_Training_044
# Index: 45, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_006, Folder Name: BraTS20_Training_006
# Index: 46, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_032, Folder Name: BraTS20_Training_032
# Index: 47, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_008, Folder Name: BraTS20_Training_008
# Index: 48, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_040, Folder Name: BraTS20_Training_040
# Index: 49, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_002, Folder Name: BraTS20_Training_002
# Index: 50, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_057, Folder Name: BraTS20_Training_057
# Index: 51, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_011, Folder Name: BraTS20_Training_011
# Index: 52, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_049, Folder Name: BraTS20_Training_049
# Index: 53, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_077, Folder Name: BraTS20_Training_077
# Index: 54, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_059, Folder Name: BraTS20_Training_059
# Index: 55, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_083, Folder Name: BraTS20_Training_083
# Index: 56, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_016, Folder Name: BraTS20_Training_016
# Index: 57, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_010, Folder Name: BraTS20_Training_010
# Index: 58, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_001, Folder Name: BraTS20_Training_001
# Index: 59, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_022, Folder Name: BraTS20_Training_022
# Index: 60, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_085, Folder Name: BraTS20_Training_085
# Index: 61, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_063, Folder Name: BraTS20_Training_063
# Index: 62, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_084, Folder Name: BraTS20_Training_084
# Index: 63, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_013, Folder Name: BraTS20_Training_013
# Index: 64, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_056, Folder Name: BraTS20_Training_056
# Index: 65, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_082, Folder Name: BraTS20_Training_082
# Index: 66, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_038, Folder Name: BraTS20_Training_038
# Index: 67, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_025, Folder Name: BraTS20_Training_025
# Index: 68, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_075, Folder Name: BraTS20_Training_075
# Index: 69, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_031, Folder Name: BraTS20_Training_031
# Index: 70, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_089, Folder Name: BraTS20_Training_089
# Index: 71, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_080, Folder Name: BraTS20_Training_080
# Index: 72, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_051, Folder Name: BraTS20_Training_051
# Index: 73, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_100, Folder Name: BraTS20_Training_100
# Index: 74, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_048, Folder Name: BraTS20_Training_048
# Index: 75, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_045, Folder Name: BraTS20_Training_045
# Index: 76, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_088, Folder Name: BraTS20_Training_088
# Index: 77, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_090, Folder Name: BraTS20_Training_090
# Index: 78, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_020, Folder Name: BraTS20_Training_020
# Index: 79, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/train/BraTS20_Training_093, Folder Name: BraTS20_Training_093
#
# Valid Data Dictionary:
# Index: 0, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/valid/BraTS20_Training_014, Folder Name: BraTS20_Training_014
# Index: 1, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/valid/BraTS20_Training_095, Folder Name: BraTS20_Training_095
# Index: 2, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/valid/BraTS20_Training_061, Folder Name: BraTS20_Training_061
# Index: 3, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/valid/BraTS20_Training_030, Folder Name: BraTS20_Training_030
# Index: 4, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/valid/BraTS20_Training_070, Folder Name: BraTS20_Training_070
# Index: 5, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/valid/BraTS20_Training_055, Folder Name: BraTS20_Training_055
# Index: 6, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/valid/BraTS20_Training_086, Folder Name: BraTS20_Training_086
# Index: 7, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/valid/BraTS20_Training_087, Folder Name: BraTS20_Training_087
# Index: 8, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/valid/BraTS20_Training_007, Folder Name: BraTS20_Training_007
# Index: 9, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/valid/BraTS20_Training_024, Folder Name: BraTS20_Training_024
# Index: 10, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/valid/BraTS20_Training_015, Folder Name: BraTS20_Training_015
# Index: 11, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/valid/BraTS20_Training_097, Folder Name: BraTS20_Training_097
# Index: 12, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/valid/BraTS20_Training_023, Folder Name: BraTS20_Training_023
# Index: 13, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/valid/BraTS20_Training_019, Folder Name: BraTS20_Training_019
# Index: 14, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/valid/BraTS20_Training_078, Folder Name: BraTS20_Training_078
# Index: 15, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/valid/BraTS20_Training_052, Folder Name: BraTS20_Training_052
# Index: 16, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/valid/BraTS20_Training_005, Folder Name: BraTS20_Training_005
# Index: 17, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/valid/BraTS20_Training_047, Folder Name: BraTS20_Training_047
# Index: 18, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/valid/BraTS20_Training_081, Folder Name: BraTS20_Training_081
# Index: 19, Absolute Path: /home/jws2215/e6691-2024spring-project-jwss-jws2215/BraTS2020/valid/BraTS20_Training_066, Folder Name: BraTS20_Training_066

# %%
## all data is stored in (240,240,155) 

class ImageDataset(Dataset):
    def __init__(self, data_folder, data_path_dictionary, image_size=(240, 240), transform=None):
        self.data_folder = data_folder
        self.image_size = image_size
        self.transform = transform

    def __len__(self):
        # print(len(self.annotations["images"]))
        return len(self.data_path_dictionary)

    def __getitem__(self, idx):
        # Load image
        image_list = self.annotations["images"]
        # print("id", image_list[idx]["id"])
        img_name = os.path.join(self.data_folder, image_list[idx]['file_name'])
        image = cv2.imread(img_name)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        folder_name = data_path_dictionary["folder_name"]
        folder_path = data_path_dictionary["absolute_path"]
        
        seg_path = os.path.join(folder_path, folder_name + '_seg.nii')
        t1_path = os.path.join(folder_path, folder_name + '_t1.nii')
        t1ce_path = os.path.join(folder_path, folder_name + '_t1ce.nii')
        t2_path = os.path.join(folder_path, folder_name + '_t2.nii')
        flair_path = os.path.join(folder_path, folder_name + '_flair.nii')
        
        # Load .nii files as nparrays
        seg_img = nib.load(seg_path).get_fdata()
        
        t1_img = nib.load(t1_path).get_fdata() #combine these ones
        t1ce_img = nib.load(t1ce_path).get_fdata()#combine these ones
        t2_img = nib.load(t2_path).get_fdata()#combine these ones
        flair_img = nib.load(flair_path).get_fdata()#combine these ones
        
        # Combine the MRI scans into a single 4-channel image
        combined_mri = np.stack([t1_img, t1ce_img, t2_img, flair_img], axis=2)
        
        # Apply transformations if specified
        if self.transform:
            image = self.transform(image)


        return image, seg_img

    

# Define transforms for data augmentation
transform = transforms.Compose([
    transforms.ToTensor(),
])
